# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt

# %%
df = pd.read_csv("input_data\ZAMG_data\daten_20000101_20151231.csv", sep=";")

stations = df["istnr"].unique()
data = pd.DataFrame()
for station in stations:
    data_dict = {station:df[df["istnr"] == station].drop("istnr", axis=1).set_index("datum")}
    new.index = pd.to_datetime(new.index)
 
    
    #data[station] = data.append(new)
    break
data_dict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-feff2b326bc2> in <module>
#       5 for station in stations:
#       6     data_dict = {station:df[df["istnr"] == station].drop("istnr", axis=1).set_index("datum")}
# ----> 7     new.index = pd.to_datetime(new.index)
#       8
#       9
#
# NameError: name 'new' is not defined

# %%
df = pd.read_csv("input_data\ZAMG_data\daten_20000101_20151231.csv", sep=";")
df["datum"] = pd.to_datetime(df["datum"])

df1 = df.set_index("datum").pivot(columns="istnr")
df1 = df1.iloc[0:6]

df1
# Out:
#            t [degC]                                                        \
# istnr         6300  6305  6430  9016  9019  9105  9110  9210  9215  9406
# datum
# 2000-01-01     -1.0  -0.4   NaN  -2.4   NaN   NaN   NaN  -3.1  -5.8   NaN
# 2000-01-02      7.9   7.1   NaN   3.4   NaN   NaN   NaN   3.1   5.0   NaN
# 2000-01-03      4.9   6.0   NaN   4.8   NaN   NaN   NaN   3.6  -0.2   NaN
# 2000-01-04      4.9   5.5   NaN   5.7   NaN   NaN   NaN   3.5  -1.6   NaN
# 2000-01-05     17.1  17.6   NaN  16.2   NaN   NaN   NaN  16.1   8.5   NaN
# 2000-01-06     14.2  14.1   NaN  15.4   NaN   NaN   NaN  14.0   7.9   NaN
#
#             ... strahl [J/cm**2]                                            \
# istnr       ...            20105 20123 20202 20212 20220 20270 20411 20412
# datum       ...
# 2000-01-01  ...              631   610   NaN   572   439   593   NaN   NaN
# 2000-01-02  ...              982   725   NaN   682   721   945   NaN   NaN
# ...
